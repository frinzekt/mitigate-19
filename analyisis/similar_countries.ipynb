# %% [markdown]
# # Similar Countries
# This notebook is about trying to find countries that are somewhat similar to Australia

# %%
import pandas as pd
import numpy as np
from scipy.stats import zscore
from sklearn import preprocessing

# %%
base_data = pd.read_csv("cleaned.csv")

base_data.drop(["Indicator Code","Country Code"],inplace=True,axis=1)
    
# FILTER BY INDICATOR NAME
INDICATORS_WE_NO_LONGER_WANT_DUE_TO_MANY_COUNTRIES_NAN = [
    "Births attended by skilled health staff (% of total)",
    "Coverage of social insurance programs (% of population)",
    "Adequacy of unemployment benefits and ALMP (% of total welfare of beneficiary households)",
    "Gini index (World Bank estimate)",
    "Physicians (per 1,000 people)",
]
INDICATOR_WE_NO_LONGER_WANT_DUE_TO_AUSTRALIA_NAN = [
    "Population living in slums (% of urban population)",
    "Literacy rate, adult total (% of people ages 15 and above)",
    "Nurses and midwives (per 1,000 people)",

]
INDICATORS_WE_WANT = [
    "Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions (% of total)",
    "Current health expenditure per capita (current US$)",
    "Current health expenditure (% of GDP)",
    "Current health expenditure per capita (current US$)",
    "GDP (current US$)",
    "GDP per capita (current US$)",
    "Hospital beds (per 1,000 people)",
    "Life expectancy at birth, total (years)",
    "People using at least basic drinking water services (% of population)",
    "People using at least basic sanitation services (% of population)",
    "People with basic handwashing facilities including soap and water (% of population)",
    "Population ages 65 and above (% of total population)",
    "Population density (people per sq. km of land area)",
    "Smoking prevalence, total (ages 15+)",
    "Urban population (% of total population)"
]

base_data = base_data[base_data["Indicator Name"].isin(INDICATORS_WE_WANT)]


df = pd.pivot_table(base_data,index=["Country Name"], columns="Indicator Name", values="2018")
non_filtered_data = pd.pivot_table(base_data,index=["Country Name"], columns="Indicator Name", values="2018",dropna=False)

# DISPLAY DATA COLUMNS WE WANT BUT NOT IN DF
#print(non_filtered_data.columns[~non_filtered_data.columns.isin(df.columns)])



# COLUMN INDEX SETTER

# MERGE RESPIRATORY DEATH
df["location"] = df.index
respiratory_df = pd.read_csv("respiratory.csv")[["location","val"]]
df = df.merge(respiratory_df,how="left").set_index("location",drop=False)
df.rename({"val":"Respiratory Death per 100k","location":"Country Name"},axis="columns",inplace=True)

print(df.columns)
merger = [
    ["beds.csv","Hospital beds (per 1,000 people)"],
    ["health.csv","Current health expenditure per capita (current US$)"],
    ["smoking.csv","Smoking prevalence, total (ages 15+)"]
]
for filename,column_name in merger:
    file_df = pd.read_csv(filename)[["Country Name",column_name]]
    file_df[column_name]=file_df[column_name].apply(lambda value: float(value) if value!=".." else np.nan)
    df = df.reset_index(drop=True).merge(file_df,how="left").set_index("Country Name",drop=False)

df.drop("Country Name",axis="columns",inplace=True)
# Out:
# Index(['GDP (current US$)', 'GDP per capita (current US$)',
#        'Life expectancy at birth, total (years)',
#        'Population ages 65 and above (% of total population)',
#        'Population density (people per sq. km of land area)',
#        'Urban population (% of total population)', 'Country Name',
#        'Respiratory Death per 100k'],
#       dtype='object')

# %% [raw]
# df.describe()

# %%
df
# Out:
#                     GDP (current US$)  GDP per capita (current US$)  \
# Country Name
# Afghanistan              1.948438e+10                    524.162881
# Albania                  1.514702e+10                   5284.380184
# Algeria                  1.737580e+11                   4114.715061
# American Samoa           6.360000e+08                  11466.690706
# Andorra                  3.218316e+09                  41793.055258
# ...                               ...                           ...
# West Bank and Gaza       1.461590e+10                   3198.866644
# World                    8.635707e+13                  11374.846763
# Yemen, Rep.              2.759126e+10                    968.159048
# Zambia                   2.700524e+10                   1556.334482
# Zimbabwe                 2.431156e+10                   1683.740577
#
#                     Life expectancy at birth, total (years)  \
# Country Name
# Afghanistan                                       64.486000
# Albania                                           78.458000
# Algeria                                           76.693000
# American Samoa                                          NaN
# Andorra                                                 NaN
# ...                                                     ...
# West Bank and Gaza                                73.895000
# World                                             72.563274
# Yemen, Rep.                                       66.096000
# Zambia                                            63.510000
# Zimbabwe                                          61.195000
#
#                     Population ages 65 and above (% of total population)  \
# Country Name
# Afghanistan                                                  2.584927
# Albania                                                     13.744736
# Algeria                                                      6.362497
# American Samoa                                                    NaN
# Andorra                                                           NaN
# ...                                                               ...
# West Bank and Gaza                                           3.133306
# World                                                        8.873129
# Yemen, Rep.                                                  2.876270
# Zambia                                                       2.099678
# Zimbabwe                                                     2.939524
#
#                     Population density (people per sq. km of land area)  \
# Country Name
# Afghanistan                                                 56.937760
# Albania                                                    104.612263
# Algeria                                                     17.730075
# American Samoa                                             277.325000
# Andorra                                                    163.842553
# ...                                                               ...
# West Bank and Gaza                                         758.984551
# World                                                       59.617881
# Yemen, Rep.                                                 53.977853
# Zambia                                                      23.341479
# Zimbabwe                                                    37.324591
#
#                     Urban population (% of total population)  \
# Country Name
# Afghanistan                                        25.495000
# Albania                                            60.319000
# Algeria                                            72.629000
# American Samoa                                     87.153000
# Andorra                                            88.062000
# ...                                                      ...
# West Bank and Gaza                                 76.164000
# World                                              55.270426
# Yemen, Rep.                                        36.642000
# Zambia                                             43.521000
# Zimbabwe                                           32.209000
#
#                     Respiratory Death per 100k  \
# Country Name
# Afghanistan                          61.257492
# Albania                              17.185137
# Algeria                              14.936240
# American Samoa                       22.482450
# Andorra                              25.029809
# ...                                        ...
# West Bank and Gaza                         NaN
# World                                      NaN
# Yemen, Rep.                                NaN
# Zambia                               87.477320
# Zimbabwe                            158.972396
#
#                     Hospital beds (per 1,000 people)  \
# Country Name
# Afghanistan                                 0.400000
# Albania                                     2.600000
# Algeria                                          NaN
# American Samoa                                   NaN
# Andorra                                          NaN
# ...                                              ...
# West Bank and Gaza                               NaN
# World                                       2.704488
# Yemen, Rep.                                 0.700000
# Zambia                                           NaN
# Zimbabwe                                    1.700000
#
#                     Current health expenditure per capita (current US$)  \
# Country Name
# Afghanistan                                                 67.122650
# Albania                                                           NaN
# Algeria                                                    258.494293
# American Samoa                                                    NaN
# Andorra                                                   4040.786621
# ...                                                               ...
# West Bank and Gaza                                                NaN
# World                                                     1061.146745
# Yemen, Rep.                                                       NaN
# Zambia                                                      67.648666
# Zimbabwe                                                   110.149620
#
#                     Smoking prevalence, total (ages 15+)
# Country Name
# Afghanistan                                          NaN
# Albania                                        28.700000
# Algeria                                        15.600000
# American Samoa                                       NaN
# Andorra                                        33.500000
# ...                                                  ...
# West Bank and Gaza                                   NaN
# World                                          20.485071
# Yemen, Rep.                                    18.400000
# Zambia                                         13.800000
# Zimbabwe                                       15.800000
#
# [263 rows x 10 columns]

# %%
df.loc["Australia"]
# Out:
# GDP (current US$)                                       1.433904e+12
# GDP per capita (current US$)                            5.739592e+04
# Life expectancy at birth, total (years)                 8.274878e+01
# Population ages 65 and above (% of total population)    1.565648e+01
# Population density (people per sq. km of land area)     3.247871e+00
# Urban population (% of total population)                8.601200e+01
# Respiratory Death per 100k                              1.754891e+01
# Hospital beds (per 1,000 people)                        3.800000e+00
# Current health expenditure per capita (current US$)     5.331818e+03
# Smoking prevalence, total (ages 15+)                    1.470000e+01
# Name: Australia, dtype: float64

# %%
df.dtypes
# Out:
# GDP (current US$)                                       float64
# GDP per capita (current US$)                            float64
# Life expectancy at birth, total (years)                 float64
# Population ages 65 and above (% of total population)    float64
# Population density (people per sq. km of land area)     float64
# Urban population (% of total population)                float64
# Respiratory Death per 100k                              float64
# Hospital beds (per 1,000 people)                        float64
# Current health expenditure per capita (current US$)     float64
# Smoking prevalence, total (ages 15+)                    float64
# dtype: object

# %%
for column in list(df.columns):
    print(column)
    
    print(df[column].isna().sum())
# Out:
# GDP (current US$)
# 22
# GDP per capita (current US$)
# 22
# Life expectancy at birth, total (years)
# 19
# Population ages 65 and above (% of total population)
# 24
# Population density (people per sq. km of land area)
# 8
# Urban population (% of total population)
# 3
# Respiratory Death per 100k
# 89
# Hospital beds (per 1,000 people)
# 103
# Current health expenditure per capita (current US$)
# 32
# Smoking prevalence, total (ages 15+)
# 77

# %%
#df.fillna(df.mean(),inplace=True)
CRITICAL_INDICATORS = [
    "GDP (current US$)",
    "GDP per capita (current US$)",
    "Life expectancy at birth, total (years)",
    "Population ages 65 and above (% of total population)",
    "Population density (people per sq. km of land area)",
    "Respiratory Death per 100k"
]

df = df[~df[CRITICAL_INDICATORS].isna().any(axis=1)]

# %%
print(df.shape)
df.head()
# Out:
# (157, 10)
#                      GDP (current US$)  GDP per capita (current US$)  \
# Country Name
# Afghanistan               1.948438e+10                    524.162881
# Albania                   1.514702e+10                   5284.380184
# Algeria                   1.737580e+11                   4114.715061
# Angola                    1.013532e+11                   3289.646664
# Antigua and Barbuda       1.610574e+09                  16726.980808
#
#                      Life expectancy at birth, total (years)  \
# Country Name
# Afghanistan                                           64.486
# Albania                                               78.458
# Algeria                                               76.693
# Angola                                                60.782
# Antigua and Barbuda                                   76.885
#
#                      Population ages 65 and above (% of total population)  \
# Country Name
# Afghanistan                                                   2.584927
# Albania                                                      13.744736
# Algeria                                                       6.362497
# Angola                                                        2.216374
# Antigua and Barbuda                                           8.799826
#
#                      Population density (people per sq. km of land area)  \
# Country Name
# Afghanistan                                                  56.937760
# Albania                                                     104.612263
# Algeria                                                      17.730075
# Angola                                                       24.713052
# Antigua and Barbuda                                         218.831818
#
#                      Urban population (% of total population)  \
# Country Name
# Afghanistan                                            25.495
# Albania                                                60.319
# Algeria                                                72.629
# Angola                                                 65.514
# Antigua and Barbuda                                    24.599
#
#                      Respiratory Death per 100k  \
# Country Name
# Afghanistan                           61.257492
# Albania                               17.185137
# Algeria                               14.936240
# Angola                                85.076690
# Antigua and Barbuda                   33.742485
#
#                      Hospital beds (per 1,000 people)  \
# Country Name
# Afghanistan                                       0.4
# Albania                                           2.6
# Algeria                                           NaN
# Angola                                            NaN
# Antigua and Barbuda                               2.1
#
#                      Current health expenditure per capita (current US$)  \
# Country Name
# Afghanistan                                                  67.122650
# Albania                                                            NaN
# Algeria                                                     258.494293
# Angola                                                      114.459641
# Antigua and Barbuda                                         673.859680
#
#                      Smoking prevalence, total (ages 15+)
# Country Name
# Afghanistan                                           NaN
# Albania                                              28.7
# Algeria                                              15.6
# Angola                                                NaN
# Antigua and Barbuda                                   NaN

# %%
standardised_df = df.apply(zscore)
standardised_df.head()
# Out:
#                      GDP (current US$)  GDP per capita (current US$)  \
# Country Name
# Afghanistan                  -0.285125                     -0.714792
# Albania                      -0.288494                     -0.481942
# Algeria                      -0.165277                     -0.539157
# Angola                       -0.221525                     -0.579516
# Antigua and Barbuda          -0.299010                      0.077783
#
#                      Life expectancy at birth, total (years)  \
# Country Name
# Afghanistan                                        -1.090284
# Albania                                             0.765381
# Algeria                                             0.530966
# Angola                                             -1.582223
# Antigua and Barbuda                                 0.556466
#
#                      Population ages 65 and above (% of total population)  \
# Country Name
# Afghanistan                                                  -0.994620
# Albania                                                       0.730034
# Algeria                                                      -0.410829
# Angola                                                       -1.051577
# Antigua and Barbuda                                          -0.034160
#
#                      Population density (people per sq. km of land area)  \
# Country Name
# Afghanistan                                                  -0.232453
# Albania                                                      -0.162139
# Algeria                                                      -0.290279
# Angola                                                       -0.279980
# Antigua and Barbuda                                           0.006321
#
#                      Urban population (% of total population)  \
# Country Name
# Afghanistan                                         -1.472951
# Albania                                              0.035241
# Algeria                                              0.568374
# Angola                                               0.260231
# Antigua and Barbuda                                 -1.511756
#
#                      Respiratory Death per 100k  \
# Country Name
# Afghanistan                            0.211383
# Albania                               -0.834787
# Algeria                               -0.888171
# Angola                                 0.776793
# Antigua and Barbuda                   -0.441756
#
#                      Hospital beds (per 1,000 people)  \
# Country Name
# Afghanistan                                       NaN
# Albania                                           NaN
# Algeria                                           NaN
# Angola                                            NaN
# Antigua and Barbuda                               NaN
#
#                      Current health expenditure per capita (current US$)  \
# Country Name
# Afghanistan                                                        NaN
# Albania                                                            NaN
# Algeria                                                            NaN
# Angola                                                             NaN
# Antigua and Barbuda                                                NaN
#
#                      Smoking prevalence, total (ages 15+)
# Country Name
# Afghanistan                                           NaN
# Albania                                               NaN
# Algeria                                               NaN
# Angola                                                NaN
# Antigua and Barbuda                                   NaN

# %%
standardised_df["total_abs_score"] = standardised_df.apply(lambda row: np.sum(np.abs(row)), axis=1)

# %%
standardised_df.head(100)
# Out:
#                      GDP (current US$)  GDP per capita (current US$)  \
# Country Name
# Seychelles                   -0.299029                      0.061339
# Kazakhstan                   -0.160941                     -0.260440
# Trinidad and Tobago          -0.281766                      0.097492
# Grenada                      -0.299353                     -0.227505
# El Salvador                  -0.279972                     -0.541459
# ...                                ...                           ...
# Greece                       -0.130800                      0.253749
# Angola                       -0.221525                     -0.579516
# Guam                         -0.295662                      1.006478
# Cameroon                     -0.270201                     -0.665371
# Kenya                        -0.232070                     -0.656884
#
#                      Life expectancy at birth, total (years)  \
# Country Name
# Seychelles                                          0.019431
# Kazakhstan                                          0.060409
# Trinidad and Tobago                                 0.090956
# Grenada                                            -0.041326
# El Salvador                                         0.053237
# ...                                                      ...
# Greece                                              1.207622
# Angola                                             -1.582223
# Guam                                                0.951452
# Cameroon                                           -1.829388
# Kenya                                              -0.843783
#
#                      Population ages 65 and above (% of total population)  \
# Country Name
# Seychelles                                                   -0.220426
# Kazakhstan                                                   -0.251751
# Trinidad and Tobago                                           0.264898
# Grenada                                                       0.092886
# El Salvador                                                  -0.113399
# ...                                                                ...
# Greece                                                        1.952541
# Angola                                                       -1.051577
# Guam                                                          0.128122
# Cameroon                                                     -0.972374
# Kenya                                                        -1.032597
#
#                      Population density (people per sq. km of land area)  \
# Country Name
# Seychelles                                                   -0.006185
# Kazakhstan                                                   -0.306444
# Trinidad and Tobago                                           0.083156
# Grenada                                                       0.167045
# El Salvador                                                   0.140608
# ...                                                                ...
# Greece                                                       -0.193623
# Angola                                                       -0.279980
# Guam                                                          0.136326
# Cameroon                                                     -0.237753
# Kenya                                                        -0.183248
#
#                      Urban population (% of total population)  \
# Country Name
# Seychelles                                          -0.121884
# Kazakhstan                                          -0.089966
# Trinidad and Tobago                                 -0.273769
# Grenada                                             -1.006210
# El Salvador                                          0.542129
# ...                                                       ...
# Greece                                               0.846807
# Angola                                               0.260231
# Guam                                                 1.527711
# Cameroon                                            -0.135613
# Kenya                                               -1.406471
#
#                      Respiratory Death per 100k  \
# Country Name
# Seychelles                             0.644285
# Kazakhstan                            -0.601544
# Trinidad and Tobago                   -0.750260
# Grenada                               -0.151169
# El Salvador                           -0.339554
# ...                                         ...
# Greece                                 0.129523
# Angola                                 0.776793
# Guam                                  -0.731308
# Cameroon                               0.774644
# Kenya                                  0.613173
#
#                      Hospital beds (per 1,000 people)  \
# Country Name
# Seychelles                                        NaN
# Kazakhstan                                        NaN
# Trinidad and Tobago                               NaN
# Grenada                                           NaN
# El Salvador                                       NaN
# ...                                               ...
# Greece                                            NaN
# Angola                                            NaN
# Guam                                              NaN
# Cameroon                                          NaN
# Kenya                                             NaN
#
#                      Current health expenditure per capita (current US$)  \
# Country Name
# Seychelles                                                         NaN
# Kazakhstan                                                         NaN
# Trinidad and Tobago                                                NaN
# Grenada                                                            NaN
# El Salvador                                                        NaN
# ...                                                                ...
# Greece                                                             NaN
# Angola                                                             NaN
# Guam                                                               NaN
# Cameroon                                                           NaN
# Kenya                                                              NaN
#
#                      Smoking prevalence, total (ages 15+)  total_abs_score  \
# Country Name
# Seychelles                                            NaN         8.899884
# Kazakhstan                                            NaN         9.258799
# Trinidad and Tobago                                   NaN         9.369601
# Grenada                                               NaN         9.512797
# El Salvador                                           NaN         9.537661
# ...                                                   ...              ...
# Greece                                                NaN        12.241969
# Angola                                                NaN        12.279149
# Guam                                                  NaN        12.304362
# Cameroon                                              NaN        12.412649
# Kenya                                                 NaN        12.495531
#
#                      distance to australia
# Country Name
# Seychelles                       -6.154724
# Kazakhstan                       -5.795809
# Trinidad and Tobago              -5.685008
# Grenada                          -5.541811
# El Salvador                      -5.516947
# ...                                    ...
# Greece                           -2.812640
# Angola                           -2.775459
# Guam                             -2.750246
# Cameroon                         -2.641959
# Kenya                            -2.559077
#
# [100 rows x 12 columns]

# %%
country_names = pd.Series(np.unique(base_data["Country Name"]))

excluded_country = country_names[~country_names.isin(standardised_df.index)]

for country in excluded_country:
    print(country)
# Out:
# American Samoa
# Andorra
# Arab World
# Aruba
# Bahamas, The
# Bermuda
# Bolivia
# British Virgin Islands
# Caribbean small states
# Cayman Islands
# Central Europe and the Baltics
# Channel Islands
# Congo, Dem. Rep.
# Congo, Rep.
# Cote d'Ivoire
# Curacao
# Czech Republic
# Dominica
# Early-demographic dividend
# East Asia & Pacific
# East Asia & Pacific (IDA & IBRD countries)
# East Asia & Pacific (excluding high income)
# Egypt, Arab Rep.
# Eritrea
# Euro area
# Europe & Central Asia
# Europe & Central Asia (IDA & IBRD countries)
# Europe & Central Asia (excluding high income)
# European Union
# Faroe Islands
# Fragile and conflict affected situations
# French Polynesia
# Gambia, The
# Gibraltar
# Greenland
# Heavily indebted poor countries (HIPC)
# High income
# Hong Kong SAR, China
# IBRD only
# IDA & IBRD total
# IDA blend
# IDA only
# IDA total
# Iran, Islamic Rep.
# Isle of Man
# Korea, Dem. People’s Rep.
# Korea, Rep.
# Kosovo
# Kyrgyz Republic
# Lao PDR
# Late-demographic dividend
# Latin America & Caribbean
# Latin America & Caribbean (excluding high income)
# Latin America & the Caribbean (IDA & IBRD countries)
# Least developed countries: UN classification
# Liechtenstein
# Low & middle income
# Low income
# Lower middle income
# Macao SAR, China
# Marshall Islands
# Micronesia, Fed. Sts.
# Middle East & North Africa
# Middle East & North Africa (IDA & IBRD countries)
# Middle East & North Africa (excluding high income)
# Middle income
# Moldova
# Monaco
# Nauru
# New Caledonia
# North America
# Northern Mariana Islands
# Not classified
# OECD members
# Other small states
# Pacific island small states
# Palau
# Post-demographic dividend
# Pre-demographic dividend
# San Marino
# Sint Maarten (Dutch part)
# Slovak Republic
# Small states
# Somalia
# South Asia
# South Asia (IDA & IBRD)
# South Sudan
# St. Kitts and Nevis
# St. Lucia
# St. Martin (French part)
# St. Vincent and the Grenadines
# Sub-Saharan Africa
# Sub-Saharan Africa (IDA & IBRD countries)
# Sub-Saharan Africa (excluding high income)
# Sudan
# Syrian Arab Republic
# Tanzania
# Turks and Caicos Islands
# Tuvalu
# United States
# Upper middle income
# Venezuela, RB
# Vietnam
# Virgin Islands (U.S.)
# West Bank and Gaza
# World
# Yemen, Rep.

# %%
australia_z_score = standardised_df.loc["Australia","total_abs_score"]
standardised_df["distance to australia"] = standardised_df["total_abs_score"] - australia_z_score

standardised_df.sort_values(by="distance to australia",inplace=True)
standardised_df
# Out:
#                           GDP (current US$)  GDP per capita (current US$)  \
# Country Name
# Seychelles                        -0.299029                      0.061339
# Kazakhstan                        -0.160941                     -0.260440
# Trinidad and Tobago               -0.281766                      0.097492
# Grenada                           -0.299353                     -0.227505
# El Salvador                       -0.279972                     -0.541459
# ...                                     ...                           ...
# Lesotho                           -0.298260                     -0.680662
# Central African Republic          -0.298536                     -0.717150
# Japan                              3.548882                      1.175084
# China                             10.493931                     -0.252414
# Singapore                         -0.010327                      2.497248
#
#                           Life expectancy at birth, total (years)  \
# Country Name
# Seychelles                                               0.019431
# Kazakhstan                                               0.060409
# Trinidad and Tobago                                      0.090956
# Grenada                                                 -0.041326
# El Salvador                                              0.053237
# ...                                                           ...
# Lesotho                                                 -2.522141
# Central African Republic                                -2.641673
# Japan                                                    1.529451
# China                                                    0.532427
# Singapore                                                1.388054
#
#                           Population ages 65 and above (% of total population)  \
# Country Name
# Seychelles                                                        -0.220426
# Kazakhstan                                                        -0.251751
# Trinidad and Tobago                                                0.264898
# Grenada                                                            0.092886
# El Salvador                                                       -0.113399
# ...                                                                     ...
# Lesotho                                                           -0.636677
# Central African Republic                                          -0.957399
# Japan                                                              2.867596
# China                                                              0.293631
# Singapore                                                          0.377470
#
#                           Population density (people per sq. km of land area)  \
# Country Name
# Seychelles                                                        -0.006185
# Kazakhstan                                                        -0.306444
# Trinidad and Tobago                                                0.083156
# Grenada                                                            0.167045
# El Salvador                                                        0.140608
# ...                                                                     ...
# Lesotho                                                           -0.214017
# Central African Republic                                          -0.305382
# Japan                                                              0.195462
# China                                                             -0.097633
# Singapore                                                         11.413274
#
#                           Urban population (% of total population)  \
# Country Name
# Seychelles                                               -0.121884
# Kazakhstan                                               -0.089966
# Trinidad and Tobago                                      -0.273769
# Grenada                                                  -1.006210
# El Salvador                                               0.542129
# ...                                                            ...
# Lesotho                                                  -1.357836
# Central African Republic                                 -0.785681
# Japan                                                     1.390681
# China                                                    -0.015301
# Singapore                                                 1.753783
#
#                           Respiratory Death per 100k  \
# Country Name
# Seychelles                                  0.644285
# Kazakhstan                                 -0.601544
# Trinidad and Tobago                        -0.750260
# Grenada                                    -0.151169
# El Salvador                                -0.339554
# ...                                              ...
# Lesotho                                     4.021779
# Central African Republic                    5.426688
# Japan                                       0.944280
# China                                      -0.872081
# Singapore                                   0.182881
#
#                           Hospital beds (per 1,000 people)  \
# Country Name
# Seychelles                                             NaN
# Kazakhstan                                             NaN
# Trinidad and Tobago                                    NaN
# Grenada                                                NaN
# El Salvador                                            NaN
# ...                                                    ...
# Lesotho                                                NaN
# Central African Republic                               NaN
# Japan                                                  NaN
# China                                                  NaN
# Singapore                                              NaN
#
#                           Current health expenditure per capita (current US$)  \
# Country Name
# Seychelles                                                              NaN
# Kazakhstan                                                              NaN
# Trinidad and Tobago                                                     NaN
# Grenada                                                                 NaN
# El Salvador                                                             NaN
# ...                                                                     ...
# Lesotho                                                                 NaN
# Central African Republic                                                NaN
# Japan                                                                   NaN
# China                                                                   NaN
# Singapore                                                               NaN
#
#                           Smoking prevalence, total (ages 15+)  \
# Country Name
# Seychelles                                                 NaN
# Kazakhstan                                                 NaN
# Trinidad and Tobago                                        NaN
# Grenada                                                    NaN
# El Salvador                                                NaN
# ...                                                        ...
# Lesotho                                                    NaN
# Central African Republic                                   NaN
# Japan                                                      NaN
# China                                                      NaN
# Singapore                                                  NaN
#
#                           total_abs_score  distance to australia
# Country Name
# Seychelles                       8.899884              -6.154724
# Kazakhstan                       9.258799              -5.795809
# Trinidad and Tobago              9.369601              -5.685008
# Grenada                          9.512797              -5.541811
# El Salvador                      9.537661              -5.516947
# ...                                   ...                    ...
# Lesotho                         21.666812               6.612204
# Central African Republic        25.870222              10.815614
# Japan                           27.427005              12.372397
# China                           30.144947              15.090338
# Singapore                       45.341808              30.287200
#
# [157 rows x 12 columns]

# %%
standardised_df.tail(5)
# Out:
#                           GDP (current US$)  GDP per capita (current US$)  \
# Country Name
# Lesotho                           -0.298260                     -0.680662
# Central African Republic          -0.298536                     -0.717150
# Japan                              3.548882                      1.175084
# China                             10.493931                     -0.252414
# Singapore                         -0.010327                      2.497248
#
#                           Life expectancy at birth, total (years)  \
# Country Name
# Lesotho                                                 -2.522141
# Central African Republic                                -2.641673
# Japan                                                    1.529451
# China                                                    0.532427
# Singapore                                                1.388054
#
#                           Population ages 65 and above (% of total population)  \
# Country Name
# Lesotho                                                           -0.636677
# Central African Republic                                          -0.957399
# Japan                                                              2.867596
# China                                                              0.293631
# Singapore                                                          0.377470
#
#                           Population density (people per sq. km of land area)  \
# Country Name
# Lesotho                                                           -0.214017
# Central African Republic                                          -0.305382
# Japan                                                              0.195462
# China                                                             -0.097633
# Singapore                                                         11.413274
#
#                           Urban population (% of total population)  \
# Country Name
# Lesotho                                                  -1.357836
# Central African Republic                                 -0.785681
# Japan                                                     1.390681
# China                                                    -0.015301
# Singapore                                                 1.753783
#
#                           Respiratory Death per 100k  \
# Country Name
# Lesotho                                     4.021779
# Central African Republic                    5.426688
# Japan                                       0.944280
# China                                      -0.872081
# Singapore                                   0.182881
#
#                           Hospital beds (per 1,000 people)  \
# Country Name
# Lesotho                                                NaN
# Central African Republic                               NaN
# Japan                                                  NaN
# China                                                  NaN
# Singapore                                              NaN
#
#                           Current health expenditure per capita (current US$)  \
# Country Name
# Lesotho                                                                 NaN
# Central African Republic                                                NaN
# Japan                                                                   NaN
# China                                                                   NaN
# Singapore                                                               NaN
#
#                           Smoking prevalence, total (ages 15+)  \
# Country Name
# Lesotho                                                    NaN
# Central African Republic                                   NaN
# Japan                                                      NaN
# China                                                      NaN
# Singapore                                                  NaN
#
#                           total_abs_score  distance to australia
# Country Name
# Lesotho                         21.666812               6.612204
# Central African Republic        25.870222              10.815614
# Japan                           27.427005              12.372397
# China                           30.144947              15.090338
# Singapore                       45.341808              30.287200
